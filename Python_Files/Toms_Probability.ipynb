# %%
# %matplotlib inline
import Some_code as sc

# %%
sc.simulate(75, 1000000, 'K+', 'mu+', 'nu_mu', product3=None, cutoff=30)
# Out:
# Time taken = 111.400190 seconds
# K+ ---> mu+ + nu_mu
# The mu+ has a probability of 0.582286 of have a momentum above 30.000000 GeV.
# The nu_mu has a probability of 0.552080 of have a momentum above 30.000000 GeV.
# The None has a probability of 0.000000 of have a momentum above 30.000000 GeV.
# The mu+ or nu_mu has a probability of 1.000000 of have a momentum above 30.000000 GeV.
# The mu+ or None has a probability of 0.000000 of have a momentum above 30.000000 GeV.
# The nu_mu or None has a probability of 0.000000 of have a momentum above 30.000000 GeV.
# The mu+ or nu_mu or None has a probability of 0.000000 of have a momentum above 30.000000 GeV.

# %%
sc.simulate(75, 1000000, 'K+', 'pi+', 'pi0', product3=None, cutoff=30)
# Out:
# Time taken = 102.850848 seconds
# K+ ---> pi+ + pi0
# The pi+ has a probability of 0.578959 of have a momentum above 30.000000 GeV.
# The pi0 has a probability of 0.575656 of have a momentum above 30.000000 GeV.
# The None has a probability of 0.000000 of have a momentum above 30.000000 GeV.
# The pi+ or pi0 has a probability of 1.000000 of have a momentum above 30.000000 GeV.
# The pi+ or None has a probability of 0.000000 of have a momentum above 30.000000 GeV.
# The pi0 or None has a probability of 0.000000 of have a momentum above 30.000000 GeV.
# The pi+ or pi0 or None has a probability of 0.000000 of have a momentum above 30.000000 GeV.

# %%
sc.simulate(75, 1000000, 'K+', 'pi+', 'pi+', product3='pi-', cutoff=30)
# Out:
# Time taken = 181.722403 seconds
# K+ ---> pi+ + pi+ + pi-
# The pi+ has a probability of 0.313723 of have a momentum above 30.000000 GeV.
# The pi+ has a probability of 0.312326 of have a momentum above 30.000000 GeV.
# The pi- has a probability of 0.312774 of have a momentum above 30.000000 GeV.
# The pi+ or pi+ has a probability of 0.609201 of have a momentum above 30.000000 GeV.
# The pi+ or pi- has a probability of 0.609579 of have a momentum above 30.000000 GeV.
# The pi+ or pi- has a probability of 0.607595 of have a momentum above 30.000000 GeV.
# The pi+ or pi+ or pi- has a probability of 0.887552 of have a momentum above 30.000000 GeV.

# %%
sc.simulate(75, 1000000, 'K+', 'pi0', 'e+', product3='nu_e', cutoff=30)
# Out:
# Time taken = 188.936063 seconds
# K+ ---> pi0 + e+ + nu_e
# The pi0 has a probability of 0.506169 of have a momentum above 30.000000 GeV.
# The e+ has a probability of 0.286686 of have a momentum above 30.000000 GeV.
# The nu_e has a probability of 0.283724 of have a momentum above 30.000000 GeV.
# The pi0 or e+ has a probability of 0.747239 of have a momentum above 30.000000 GeV.
# The pi0 or nu_e has a probability of 0.744934 of have a momentum above 30.000000 GeV.
# The e+ or nu_e has a probability of 0.558598 of have a momentum above 30.000000 GeV.
# The pi0 or e+ or nu_e has a probability of 0.974192 of have a momentum above 30.000000 GeV.

# %%
sc.simulate(75, 1000000, 'K+', 'pi0', 'mu+', product3='nu_mu', cutoff=30)
# Out:
# Time taken = 186.109204 seconds
# K+ ---> pi0 + mu+ + nu_mu
# The pi0 has a probability of 0.470040 of have a momentum above 30.000000 GeV.
# The mu+ has a probability of 0.406579 of have a momentum above 30.000000 GeV.
# The nu_mu has a probability of 0.199159 of have a momentum above 30.000000 GeV.
# The pi0 or mu+ has a probability of 0.803051 of have a momentum above 30.000000 GeV.
# The pi0 or nu_mu has a probability of 0.647234 of have a momentum above 30.000000 GeV.
# The mu+ or nu_mu has a probability of 0.591481 of have a momentum above 30.000000 GeV.
# The pi0 or mu+ or nu_mu has a probability of 0.965988 of have a momentum above 30.000000 GeV.

# %%
sc.simulate(75, 1000000, 'K+', 'pi+', 'pi0', product3='pi0', cutoff=30)
# Out:
# Time taken = 181.610311 seconds
# K+ ---> pi+ + pi0 + pi0
# The pi+ has a probability of 0.331711 of have a momentum above 30.000000 GeV.
# The pi0 has a probability of 0.313140 of have a momentum above 30.000000 GeV.
# The pi0 has a probability of 0.313356 of have a momentum above 30.000000 GeV.
# The pi+ or pi0 has a probability of 0.624627 of have a momentum above 30.000000 GeV.
# The pi+ or pi0 has a probability of 0.624624 of have a momentum above 30.000000 GeV.
# The pi0 or pi0 has a probability of 0.608796 of have a momentum above 30.000000 GeV.
# The pi+ or pi0 or pi0 has a probability of 0.899840 of have a momentum above 30.000000 GeV.

# %%
sc.simulate(75, 1000000, 'K+', 'pi+', 'nu_e', product3='nu_ebar', cutoff=30)
# Out:
# Time taken = 175.086907 seconds
# K+ ---> pi+ + nu_e + nu_ebar
# The pi+ has a probability of 0.512060 of have a momentum above 30.000000 GeV.
# The nu_e has a probability of 0.281643 of have a momentum above 30.000000 GeV.
# The nu_ebar has a probability of 0.281824 of have a momentum above 30.000000 GeV.
# The pi+ or nu_e has a probability of 0.747893 of have a momentum above 30.000000 GeV.
# The pi+ or nu_ebar has a probability of 0.748327 of have a momentum above 30.000000 GeV.
# The nu_e or nu_ebar has a probability of 0.552825 of have a momentum above 30.000000 GeV.
# The pi+ or nu_e or nu_ebar has a probability of 0.973518 of have a momentum above 30.000000 GeV.
